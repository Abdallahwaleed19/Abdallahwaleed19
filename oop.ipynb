# %% [markdown]
# ## OOP Projects

# %%
class Bank_account():
    def __init__(self,balance,account_number):
        self.balance = balance
        self.account_number = account_number
     
    def display(self):
        print (f"the balance number is {self.balance},and the account number is {self.account_number}"  )  
    def display_deposite(self,deposite):
        self.deposite = deposite
        if deposite >= self.balance :
            print("No money")
        else :
          result = (self.balance) + (self.deposite)
          print ("the deposite is  = ",result)
    def display_with_draw(self,witdraw):
        self.withdraw = witdraw
        result1 = (self.balance) - (self.withdraw)
        print ("the withdraw is = ",result1) 
person1 = Bank_account(1000000,3041102178888)
person1.display()
person1.display_deposite(1000000000000)
person1.display_with_draw(500)
# Out:
# the balance number is 1000000,and the account number is 3041102178888
# No money
# the withdraw is =  999500

# %% [markdown]
# ## Inheretance

# %%
class animal ():
    def __init__(self,speak):
        self.speak = speak
    def display (self):
        print (f"the speak is {self.speak} ")    
class dog (animal):
    pass
class cat (animal):
    pass 
dog1 = dog("HAOHAO")
cat1 = cat("MeaoMeao")
dog1.display()
cat1.display()
# Out:
# the speak is HAOHAO
# the speak is MeaoMeao

# %%
class student():
    count_student = 0
    def __init__(self,name,GPA):
        self.name  = name
        self.GPA = GPA
        student.count_student +=1
    def displaycount (self)  :
        print("Total is  = ",student.count_student) 
    def displaystudent(self):
        print(f"student name : {self.name}, and his GPA is : {self.GPA}")    
       
student1 = student("Abdallah",3.5)
student2 = student("Ali",3) 
student3 = student("Ahmed",2.5)
student1.displaystudent()
student2.displaystudent()
student3.displaystudent()
# Out:
# student name : Abdallah, and his GPA is : 3.5
# student name : Ali, and his GPA is : 3
# student name : Ahmed, and his GPA is : 2.5

# %% [markdown]
# # Scarping Websites

# %% [markdown]
# # First Data

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

# %%
page = requests.get("https://en.wikipedia.org/wiki/List_of_countries_by_population_(United_Nations)")
src = page.content
soup = BeautifulSoup(src, 'html.parser')
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of countries by population (United Nations) - Wikipedia</title>
# ...

# %%
table = soup.find('table', {'class': 'wikitable'})
print(table)
# Out:
# <table class="wikitable sortable mw-datatable sticky-header static-row-numbers sort-under col1left col5left col6left" style="text-align:right">
# <caption>List of countries and inhabited territories by total population. United Nations
# </caption>
# <tbody><tr>
# <th>Country or territory
# </th>
# <th>Population<br/>(1 July 2022)
# </th>
# <th>Population<br/>(1 July 2023)
# </th>
# <th>Change<br/>(%)
# </th>
# <th style="max-width:9em;"><a href="/wiki/United_Nations_geoscheme" title="United Nations geoscheme">UN continental<br/>region</a><sup class="reference" id="cite_ref-UNregions_1-1"><a href="#cite_note-UNregions-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
# </th>
# ...

# %%
table_of_th = table.find_all('th')
print(table_of_th)
# Out:
# [<th>Country or territory
# </th>, <th>Population<br/>(1 July 2022)
# </th>, <th>Population<br/>(1 July 2023)
# </th>, <th>Change<br/>(%)
# </th>, <th style="max-width:9em;"><a href="/wiki/United_Nations_geoscheme" title="United Nations geoscheme">UN continental<br/>region</a><sup class="reference" id="cite_ref-UNregions_1-1"><a href="#cite_note-UNregions-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
# </th>, <th style="max-width:8em;"><a href="/wiki/List_of_countries_and_territories_by_the_United_Nations_geoscheme" title="List of countries and territories by the United Nations geoscheme">UN statistical<br/>subregion</a><sup class="reference" id="cite_ref-UNregions_1-2"><a href="#cite_note-UNregions-1"><span class="cite-bracket">[</span>1<span class="cite-bracket">]</span></a></sup>
# </th>]

# %%
headers = []
for th in table_of_th :
    headers.append(th.text.strip())
print(headers)
# Out:
# ['Country or territory', 'Population(1 July 2022)', 'Population(1 July 2023)', 'Change(%)', 'UN continentalregion[1]', 'UN statisticalsubregion[1]']

# %%
rows = []
for row in table.find_all('tr')[1:]:  
    columns = row.find_all('td')
    if len(columns) > 1:  
        row_data = [col.text.strip() for col in columns]
        rows.append(row_data)
print(rows)
# Out:
# [['World', '8,021,407,192', '8,091,734,930', '+0.88%', '–', '–'], ['India', '1,425,423,212', '1,438,069,596', '+0.89%', 'Asia', 'Southern Asia'], ['China[a]', '1,425,179,569', '1,422,584,933', '−0.18%', 'Asia', 'Eastern Asia'], ['United States', '341,534,046', '343,477,335', '+0.57%', 'Americas', 'Northern America'], ['Indonesia', '278,830,529', '281,190,067', '+0.85%', 'Asia', 'South-eastern Asia'], ['Pakistan', '243,700,667', '247,504,495', '+1.56%', 'Asia', 'Southern Asia'], ['Nigeria', '223,150,896', '227,882,945', '+2.12%', 'Africa', 'Western Africa'], ['Brazil', '210,306,415', '211,140,729', '+0.40%', 'Americas', 'South America'], ['Bangladesh', '169,384,897', '171,466,990', '+1.23%', 'Asia', 'Southern Asia'], ['Russia', '145,579,899', '145,440,500', '−0.10%', 'Europe', 'Eastern Europe'], ['Mexico', '128,613,117', '129,739,759', '+0.88%', 'Americas', 'Central America'], ['Ethiopia', '125,384,287', '128,691,692', '+2.64%', 'Africa', 'Eastern Africa'], ['Japan', '124,997,578', '1
# ...

# %%
df = pd.DataFrame(rows, columns=headers)
df
# Out:
#                   Country or territory Population(1 July 2022)  \
# 0                                World           8,021,407,192
# 1                                India           1,425,423,212
# 2                             China[a]           1,425,179,569
# 3                        United States             341,534,046
# 4                            Indonesia             278,830,529
# ..                                 ...                     ...
# 233        Montserrat (United Kingdom)                   4,453
# 234  Falkland Islands (United Kingdom)                   3,490
# 235              Tokelau (New Zealand)                   2,290
# 236                 Niue (New Zealand)                   1,821
# 237                    Vatican City[x]                     505
#
#     Population(1 July 2023) Change(%) UN continentalregion[1]  \
# 0             8,091,734,930    +0.88%                       –
# 1             1,438,069,596    +0.89%                    Asia
# ...

# %%
df.to_csv('countries_population.csv', index=False)
print("Data saved to 'countries_population.csv'")
# Out:
# Data saved to 'countries_population.csv'

# %% [markdown]
# # Second Data

# %%
page2 = requests.get("https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_area")
src2 = page2.content
soup2 = BeautifulSoup(src2, 'html.parser')
print(soup2)
# Out:
# <!DOCTYPE html>
#
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-sticky-header-enabled vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>List of countries and dependencies by area - Wikipedia</title>
# ...

# %%
table2 = soup2.find('table', {'class': 'wikitable'})
print(table2)
# Out:
# <table class="wikitable sortable sticky-header col2left" style="text-align:right">
# <tbody><tr>
# <th></th>
# <th style="width:18em">Country / dependency
# </th>
# <th data-sort-type="number" style="width:9.7em">Total<br/>in km<sup>2</sup> (mi<sup>2</sup>)
# </th>
# <th data-sort-type="number" style="width:9.7em">Land<br/>in km<sup>2</sup> (mi<sup>2</sup>)
# </th>
# <th data-sort-type="number" style="width:7.5em">Water<br/>in km<sup>2</sup> (mi<sup>2</sup>)
# </th>
# <th data-sort-type="number">%<br/>water</th>
# <th class="unsortable">
# </th></tr>
# <tr>
# <td><span data-sort-value="5000000000000000000♠" style="display:none"></span> –</td>
# <td><b><span class="flagicon" style="padding-left:25px;"> </span><a href="/wiki/Earth" title="Earth">Earth</a></b></td>
# <td>510,072,000 (196,940,000)</td>
# <td>148,940,000 (57,506,000)</td>
# <td>361,132,000 (139,434,000)</td>
# <td>70.8</td>
# <td>
# </td></tr>
# <tr>
# <td><span data-sort-value="7000100000000000000♠">1</span></td>
# ...

# %%
table_of_th2 = table2.find_all('th')
print(table_of_th2)
# Out:
# [<th></th>, <th style="width:18em">Country / dependency
# </th>, <th data-sort-type="number" style="width:9.7em">Total<br/>in km<sup>2</sup> (mi<sup>2</sup>)
# </th>, <th data-sort-type="number" style="width:9.7em">Land<br/>in km<sup>2</sup> (mi<sup>2</sup>)
# </th>, <th data-sort-type="number" style="width:7.5em">Water<br/>in km<sup>2</sup> (mi<sup>2</sup>)
# </th>, <th data-sort-type="number">%<br/>water</th>, <th class="unsortable">
# </th>]

# %%
headers2 = []
for th2 in table_of_th2 :
    headers2.append(th2.text.strip())
print(headers2)
# Out:
# ['', 'Country / dependency', 'Totalin km2 (mi2)', 'Landin km2 (mi2)', 'Waterin km2 (mi2)', '%water', '']

# %%
rows2 = []
for row2 in table2.find_all('tr')[1:]:  
    columns2 = row2.find_all('td')
    if len(columns2) > 1:  # Ensure the row has data
        row_data2 = [col2.text.strip() for col2 in columns2]
        rows2.append(row_data2)
print(rows2)
# Out:
# [['–', 'Earth', '510,072,000 (196,940,000)', '148,940,000 (57,506,000)', '361,132,000 (139,434,000)', '70.8', ''], ['1', 'Russia', '17,098,246 (6,601,667)', '16,376,870 (6,323,142)', '721,380 (278,530)', '4.2', '[b]'], ['–', 'Antarctica', '14,200,000 (5,480,000)', '14,200,000 (5,480,000)', '0', '0', '[c]'], ['2', 'Canada', '9,984,670 (3,855,100)', '9,093,507 (3,511,021)', '891,163 (344,080)', '8.9', '[d]'], ['3/4[e]', 'China', '9,596,960 (3,705,410)', '9,326,410 (3,600,950)', '270,550 (104,460)', '2.8', '[f]'], ['United States', '9,525,067 (3,677,647)', '9,147,593 (3,531,904)', '377,424 (145,724)', '4.0', '[g]'], ['5', 'Brazil', '8,510,346 (3,285,862)', '8,460,415 (3,266,583)', '55,352 (21,372)', '0.6', '[h]'], ['6', 'Australia', '7,741,220 (2,988,900)', '7,682,300 (2,966,200)', '58,920 (22,750)', '0.8', '[i]'], ['7', 'India', '3,287,263 (1,269,219)', '2,973,190 (1,147,960)', '314,070 (121,260)', '9.6', '[j]'], ['8', 'Argentina', '2,780,400 (1,073,500)', '2,736,690 (1,056,640)', '43,
# ...

# %%
df2 = pd.DataFrame(rows2, columns=headers2)
df2
# Out:
#                                 Country / dependency  \
# 0         –                                    Earth
# 1         1                                   Russia
# 2         –                               Antarctica
# 3         2                                   Canada
# 4    3/4[e]                                    China
# ..      ...                                      ...
# 259       –  Ashmore and Cartier Islands (Australia)
# 260       –            Coral Sea Islands (Australia)
# 261       –               Spratly Islands (disputed)
# 262     194                                   Monaco
# 263     195                             Vatican City
#
#              Totalin km2 (mi2)          Landin km2 (mi2)  \
# 0    510,072,000 (196,940,000)  148,940,000 (57,506,000)
# 1       17,098,246 (6,601,667)    16,376,870 (6,323,142)
# 2       14,200,000 (5,480,000)    14,200,000 (5,480,000)
# 3        9,984,670 (3,855,100)     9,093,507 (3,511,021)
# ...

# %%
df2.to_csv('countries_population2.csv', index=False)
print("Data saved to 'countries_population.csv'")
# Out:
# Data saved to 'countries_population.csv'

# %%
merged_df = pd.merge(df, df2, left_on='Country or territory', right_on='Country / dependency', how='inner')
merged_df.to_csv('merged_countries_population.csv', index=False)
print("Merged CSV saved as 'merged_countries_population.csv'")
# Out:
# Merged CSV saved as 'merged_countries_population.csv'
